# %% [markdown]
# # Testing Jupyter app.
# ## Sub headline.
#
# **Test**
#
# more things to say.

# %%
import pandas as pd

# %%
import pandas_datareader as dr

# %%
# %matplotlib inline

# %%
df = dr.data.get_data_yahoo('msft', start='2020-09-27', end='2020-10-07')
df
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-09-28  212.570007  208.059998  210.880005  209.440002  32004900
# 2020-09-29  210.070007  206.809998  209.350006  207.259995  24221900
# 2020-09-30  211.979996  206.539993  207.729996  210.330002  33780700
# 2020-10-01  213.990005  211.320007  213.490005  212.460007  27158400
# 2020-10-02  210.990005  205.539993  208.000000  206.190002  33154800
# 2020-10-05  210.410004  206.979996  207.220001  210.380005  21331600
# 2020-10-06  210.179993  204.820007  208.820007  205.910004  28554300
# 2020-10-07  210.110001  206.720001  207.059998  209.830002  25681100
#
#              Adj Close
# Date
# 2020-09-28  209.440002
# 2020-09-29  207.259995
# 2020-09-30  210.330002
# 2020-10-01  212.460007
# 2020-10-02  206.190002
# 2020-10-05  210.380005
# 2020-10-06  205.910004
# 2020-10-07  209.830002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8 entries, 2020-09-28 to 2020-10-07
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       8 non-null      float64
#  1   Low        8 non-null      float64
#  2   Open       8 non-null      float64
#  3   Close      8 non-null      float64
#  4   Volume     8 non-null      int64
#  5   Adj Close  8 non-null      float64
# dtypes: float64(5), int64(1)
# memory usage: 448.0 bytes

# %%
df['Close'].plot();

# %%
df['Close'].plot(figsize=(15,5));

# %%
df[['Open', 'Close']].plot(figsize=(15,5))

# %%
df.loc['2020-10-01': '2020-10-07',['Open', 'Close']].plot(figsize=(15,5))

# %%
df['Close'].pct_change().plot();

# %%
df['2020-10']
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-10-01  213.990005  211.320007  213.490005  212.460007  27158400
# 2020-10-02  210.990005  205.539993  208.000000  206.190002  33154800
# 2020-10-05  210.410004  206.979996  207.220001  210.380005  21331600
# 2020-10-06  210.179993  204.820007  208.820007  205.910004  28554300
# 2020-10-07  210.110001  206.720001  207.059998  209.830002  25681100
#
#              Adj Close
# Date
# 2020-10-01  212.460007
# 2020-10-02  206.190002
# 2020-10-05  210.380005
# 2020-10-06  205.910004
# 2020-10-07  209.830002
